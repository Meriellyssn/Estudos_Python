# %%
#1. Criando LISTAS

dados_extraidos = []

dados_extraidos = ['PostgreSQL', 'MongoDB', 'MySQL']
tempo_de_processamento = [12, 45, 8, 38]

# Exemplo: [Nome do Job, ID, Tempo em segundos, Sucesso?]
status_do_job = ['Carga_vendas', 1045, 45.5, True]

print(dados_extraidos)
# Out:
# ['PostgreSQL', 'MongoDB', 'MySQL']

# %% [markdown]
# Exercício 1: O Catálogo de Fontes de Dados
# Crie uma variável chamada fontes_de_dados. Atribua a ela uma lista contendo o nome de 3 formatos de arquivos ou sistemas de onde você extrairia dados (ex: "CSV", "API", "SQL"). Lembre-se de usar aspas, pois são textos! Ao final, use o print() para exibir sua lista na tela.

# %%
fonte_de_dados = ['CSV', 'API', 'SQL']
print(f'Os formatos das fontes de dados são:{fonte_de_dados}')
# Out:
# Os formatos das fontes de dados são:['CSV', 'API', 'SQL']

# %% [markdown]
# Exercício 2: O Log do Servidor
# Imagine que você está criando um sistema de monitoramento para o seu cluster de dados. Crie uma lista chamada status_servidor que contenha, exatamente nesta ordem:
#
# O nome do servidor (texto, ex: "Servidor_AWS_01")
#
# A quantidade de memória RAM em GB (número inteiro, ex: 16)
#
# A porcentagem de uso da CPU (número decimal, ex: 85.5 - lembre-se de usar ponto em vez de vírgula para decimais no Python!)
# Imprima a lista na tela.

# %%
status_servidor = ['Servidor_AWS_01', 16, 85.5]
print(f'{status_servidor[0]}; memoria RAM/GB: {status_servidor[1]}; CPU: {status_servidor[2]}')
# Out:
# Servidor_AWS_01; memoria RAM/GB: 16; CPU: 85.5

# %% [markdown]
# Exercício 3: Segmentação de IDs
# Em processamento de dados, às vezes dividimos as tarefas. Crie duas listas separadas:
#
# Uma lista chamada ids_pares contendo os números pares de 2 até 10.
#
# Outra lista chamada ids_impares contendo os números ímpares de 1 até 9.
# Em seguida, imprima as duas listas na tela.

# %%
ids_pares = [2,4,6,8,10]
ids_impares = [1, 3, 5, 7, 9]
print(f'Os valores pares são: {ids_pares}; e os ímpares são: {ids_impares}')
# Out:
# Os valores pares são: [2, 4, 6, 8, 10]; e os ímpares são: [1, 3, 5, 7, 9]
