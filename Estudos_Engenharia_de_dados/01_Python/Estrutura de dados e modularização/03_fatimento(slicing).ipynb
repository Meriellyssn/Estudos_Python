# %% [markdown]
# A Regra de Ouro do Fatiamento<br>
# Para fatiar uma lista, usamos os colchetes [ ] (como fazíamos para acessar um item só), mas adicionamos dois pontos : para definir um intervalo. A fórmula completa tem três partes:

# %%
# minha_lista[inicio : fim : passo]

# %% [markdown]
# inicio: O índice de onde a fatia começa (incluído).<br>
#
# fim: O índice onde a fatia termina (excluído - o Python pega até um item antes desse número).<br>
#
# passo: De quantos em quantos itens ele vai pular (opcional, o padrão é 1).

# %%
# Índices:        0    1    2    3    4    5
vendas_meses = [150, 200, 180, 220, 250, 300]

# %% [markdown]
# 1. Fatiamento Básico (início e fim):<br>
# Pegar as vendas do índice 1 ao índice 3. Lembre-se: o índice 4 fica de fora!

# %%
# Índices:        0    1    2    3    4    5
vendas_meses = [150, 200, 180, 220, 250, 300]

trimestre = vendas_meses[1:4]
print(trimestre) # Resultado: [200, 180, 220]

primeiros_tres = vendas_meses[:3] # Pega do começo (0) até o índice 2
ultimos_tres = vendas_meses[3:]   # Pega do índice 3 até o final da lista
print(primeiros_tres)
print(ultimos_tres)

meses_alternados = vendas_meses[0:5:2]
print(meses_alternados) # Resultado: [150, 180, 250]
# Out:
# [200, 180, 220]
# [150, 200, 180]
# [220, 250, 300]
# [150, 180, 250]
