# %%
variavel1 = input('Digite um número: ')
if variavel1 >= str(0):
    print('Número Positivo.')
    print(f'O número é:{variavel1}')
else:
    print('Número Negativo.')
    print(f'O número é: {variavel1}')
# Out:
# Número Positivo.
# O número é:1

# %%
nome = 'João'
dia_vencimento = 10
valor_fatura = 149.90
print(f'Olá, caro {nome}, \nA sua fatura com vencimento em {dia_vencimento} de janeiro, \nno valor de R${valor_fatura} está próxima do vencimento.\nFavor pagar até o prazo para evitar multas.')
# Out:
# Olá, caro João,
# A sua fatura com vencimento em 10 de janeiro,
# no valor de R$149.9 está próxima do vencimento.
# Favor pagar até o prazo para evitar multas.

# %%
#Interação entre variáveis
num1 = 10
num2 = 5.2
print(f'O resultado de {num1} + {num2} é igual a {num1 + num2}')
# Out:
# O resultado de 10 + 5.2 é igual a 15.2

# %%
num1 = 5
num2 = 8.2
soma = int(num1) + int(num2)
print(soma)
# Out:
# 13

# %%
#Operadores de Atribuição
nome = ''
idade = 0
nome = input('Por favor, digite o seu nome: ').strip()
idade = int(input('Digite a sua idade: '))
print(f'Olá, {nome}!'
      f' Parabéns pelos seus {idade} anos!')
# Out:
# Olá, Merielly! Parabéns pelos seus 31 anos!

# %%
#Atribuições especiais
var1 = 4
#var1 = var1 + 5
var1 += 5
print(var1)
# Out:
# 9

# %%
#Operadores de identidade
aluguel = 250
energia = 250
agua = 65
print(aluguel is energia)
# Out:
# True

# %%
nome = 'Merielly'
mensagem = f'''
Olá meu nome é {nome},
Eu estou aprendendo Python.'''
print(mensagem)
# Out:
# Olá meu nome é Merielly,
# Eu estou aprendendo Python.

# %%
print('''
    ========== MENU ==========
    1 - Depositar
    2 - Sacar
    0 - Sair
    ==========================
  Obrigado por usar nosso sistema
''')
# Out:
#     ========== MENU ==========
#     1 - Depositar
#     2 - Sacar
#     0 - Sair
#     ==========================
#   Obrigado por usar nosso sistema
