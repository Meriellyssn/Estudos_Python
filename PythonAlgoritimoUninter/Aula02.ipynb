# %%
#O primeiro programa
print('Olá, mundo!')

# %%
#Exercicio 2.1
x = int(input('Digite um número inteiro: '))
y = int(input('Digite outro número inteiro: '))
soma = x + y
print(f'O resultado da soma de {x} + {y} é igual a >> {soma}')
# Out:
# O resultado da soma de 5 + 5 é igual a >> 10
